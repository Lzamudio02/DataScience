# %%
# !pip install folium
# !pip install geopy

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

import seaborn as sns
import matplotlib.pyplot as plt
import random

import folium
from folium.plugins import HeatMap
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2023, 6, 8, 18, 36, 13, 694174)

# %% [markdown]
# # folium
# ##### https://python-visualization.github.io/folium/

# %% [markdown]
# ## LATITUD (paralelos)
# ##### es la distancia que existe desde un paralelo al Ecuador. Su valor oscila desde 0º (ecuador) hasta 90º (los polos)
#
# ## LONGITUD (meridianos)
# ##### es la distancia que existe desde un meridiano al meridiano de Greenwich. Su valor oscila desde 0º (meridiano de Greenwich) hasta 180º (meridiano opuesto a Greenwich)

# %% [markdown]
# # Centrar el mapa

# %%
teatro_colon = (-34.60053037141119, -58.38348489577889) # (latitud (norte - sur), longitud (este - oeste))

# %%
m = folium.Map(location=teatro_colon)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a709e33db424027566d0d788d4aa10f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a709e33db424027566d0d788d4aa10f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a709e33db424027566d0d788d4aa10f9 = L.map(
#                 &quot;map_a709e33db424027566d0d788d4aa10f9&quot;,
#                 {
#                     center: [-34.60053037141119, -58.38348489577889],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62ff6474522edf547c884b5845773bb5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a709e33db424027566d0d788d4aa10f9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Agregar marcadores

# %%
m = folium.Map(location=teatro_colon, zoom_start=12)

# %%
tooltip = "Cliquear"

# %%
folium.Marker(
    teatro_colon, popup="<i>Teatro Colón</i>", tooltip=tooltip
).add_to(m)
folium.Marker(
    [-34.58274234940554, -58.41676748444711], popup="<b>Jardín Botánico</b>", tooltip=tooltip
).add_to(m);

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a751cdd7f86db68b3622be61855a7d78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a751cdd7f86db68b3622be61855a7d78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a751cdd7f86db68b3622be61855a7d78 = L.map(
#                 &quot;map_a751cdd7f86db68b3622be61855a7d78&quot;,
#                 {
#                     center: [-34.60053037141119, -58.38348489577889],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb032ed6b34cd2f258c778c3c71eb64a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a751cdd7f86db68b3622be61855a7d78);
#
#
#             var marker_b3205254519c9431e648aaac62d22a39 = L.marker(
#                 [-34.60053037141119, -58.38348489577889],
#                 {}
#             ).addTo(map_a751cdd7f86db68b3622be61855a7d78);
#
#
#         var popup_c429ebf4978d0d003bccf787cb266294 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_247f967717b0694bf71eb98b2aaf6dd8 = $(`&lt;div id=&quot;html_247f967717b0694bf71eb98b2aaf6dd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Teatro Colón&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_c429ebf4978d0d003bccf787cb266294.setContent(html_247f967717b0694bf71eb98b2aaf6dd8);
#
#
#
#         marker_b3205254519c9431e648aaac62d22a39.bindPopup(popup_c429ebf4978d0d003bccf787cb266294)
#         ;
#
#
#
#
#             marker_b3205254519c9431e648aaac62d22a39.bindTooltip(
#                 `&lt;div&gt;
#                      Cliquear
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d04ab6594f2da1d7e55f010ea6b53cdf = L.marker(
#                 [-34.58274234940554, -58.41676748444711],
#                 {}
#             ).addTo(map_a751cdd7f86db68b3622be61855a7d78);
#
#
#         var popup_be4752f47ba0d584b47e5e82257965ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f02c8066e0d9eba9727c8292434cf3f7 = $(`&lt;div id=&quot;html_f02c8066e0d9eba9727c8292434cf3f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Jardín Botánico&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_be4752f47ba0d584b47e5e82257965ba.setContent(html_f02c8066e0d9eba9727c8292434cf3f7);
#
#
#
#         marker_d04ab6594f2da1d7e55f010ea6b53cdf.bindPopup(popup_be4752f47ba0d584b47e5e82257965ba)
#         ;
#
#
#
#
#             marker_d04ab6594f2da1d7e55f010ea6b53cdf.bindTooltip(
#                 `&lt;div&gt;
#                      Cliquear
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=teatro_colon, zoom_start=12)

# %%
folium.Marker(
    location=[-34.61641381404576, -58.44802536214192],
    popup="Estadio Arquitecto Ricardo Etcheverri",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[-34.61594113052585, -58.433532596354645],
    popup="Parque Rivadavia",
    icon=folium.Icon(color="green"),
).add_to(m)

folium.Marker(
    location=[-34.587492320231036, -58.430044369120864],
    popup="Plaza Serrano",
    icon=folium.Icon(color="red", icon="info-sign"),
).add_to(m);

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad = L.map(
#                 &quot;map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad&quot;,
#                 {
#                     center: [-34.60053037141119, -58.38348489577889],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f4233327575d1147b33d1859735e883 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad);
#
#
#             var marker_d7b10cac772e47a03d52b75cf59b884a = L.marker(
#                 [-34.61641381404576, -58.44802536214192],
#                 {}
#             ).addTo(map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad);
#
#
#             var icon_67f0629f3f301487f55f3f90bc8c3715 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7b10cac772e47a03d52b75cf59b884a.setIcon(icon_67f0629f3f301487f55f3f90bc8c3715);
#
#
#         var popup_cd233228134477b550985fb2856d5fbb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3948974543a679e863e6d1513d2a1be5 = $(`&lt;div id=&quot;html_3948974543a679e863e6d1513d2a1be5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estadio Arquitecto Ricardo Etcheverri&lt;/div&gt;`)[0];
#                 popup_cd233228134477b550985fb2856d5fbb.setContent(html_3948974543a679e863e6d1513d2a1be5);
#
#
#
#         marker_d7b10cac772e47a03d52b75cf59b884a.bindPopup(popup_cd233228134477b550985fb2856d5fbb)
#         ;
#
#
#
#
#             var marker_1f05c35bc37abd7cf6b45c6f5619d4c5 = L.marker(
#                 [-34.61594113052585, -58.433532596354645],
#                 {}
#             ).addTo(map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad);
#
#
#             var icon_60d468e74ccaa4db40318f32dce12484 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f05c35bc37abd7cf6b45c6f5619d4c5.setIcon(icon_60d468e74ccaa4db40318f32dce12484);
#
#
#         var popup_0a14629cd70095699d6082e74800408c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc3bceac132bdd30e041fe5581a520a1 = $(`&lt;div id=&quot;html_bc3bceac132bdd30e041fe5581a520a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Parque Rivadavia&lt;/div&gt;`)[0];
#                 popup_0a14629cd70095699d6082e74800408c.setContent(html_bc3bceac132bdd30e041fe5581a520a1);
#
#
#
#         marker_1f05c35bc37abd7cf6b45c6f5619d4c5.bindPopup(popup_0a14629cd70095699d6082e74800408c)
#         ;
#
#
#
#
#             var marker_709292584a68c896a79d68788c5f793e = L.marker(
#                 [-34.587492320231036, -58.430044369120864],
#                 {}
#             ).addTo(map_8fa4a4ff9c3d77bd6e63d4ff9c5c33ad);
#
#
#             var icon_39631c98030dc8c3fab3de01759f4af6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_709292584a68c896a79d68788c5f793e.setIcon(icon_39631c98030dc8c3fab3de01759f4af6);
#
#
#         var popup_b6c6ce6dabecd30e242fd19ff9908b9e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44c909b6c9ab697a9b69c6ee9f61bb05 = $(`&lt;div id=&quot;html_44c909b6c9ab697a9b69c6ee9f61bb05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Plaza Serrano&lt;/div&gt;`)[0];
#                 popup_b6c6ce6dabecd30e242fd19ff9908b9e.setContent(html_44c909b6c9ab697a9b69c6ee9f61bb05);
#
#
#
#         marker_709292584a68c896a79d68788c5f793e.bindPopup(popup_b6c6ce6dabecd30e242fd19ff9908b9e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Guardar mapa

# %%
fecha = datetime.now().strftime('%Y%m%d_%H%M')
rnd_num = str(random.randint(100,999))

fecha, rnd_num
# Out:
# ('20230608_1836', '711')

# %%
nombre_del_mapa = fecha + '_Buenos_Aires_' + rnd_num + '.html'
m.save(nombre_del_mapa)

print(nombre_del_mapa, 'guardado ok')
# Out:
# 20230608_1836_Buenos_Aires_711.html guardado ok

# %% [markdown]
# ## Polyline

# %%
m = folium.Map(location=[-34.6004232609843, -58.38300902393554], zoom_start=13)

trail_coordinates = [
    (-34.588850218149815, -58.38153690012031),
    (-34.59315242757882, -58.382420174409454),
    (-34.59327361335069, -58.38227296202792),
    (-34.6041796088788, -58.38153690012031),
    (-34.61393279363598, -58.38107550326964),
    (-34.62211391663683, -58.38089990008334)
]

folium.PolyLine(trail_coordinates, tooltip="Avda 9 de Julio").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ef122c3d9d735582e2f4798c3af9677 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ef122c3d9d735582e2f4798c3af9677&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ef122c3d9d735582e2f4798c3af9677 = L.map(
#                 &quot;map_6ef122c3d9d735582e2f4798c3af9677&quot;,
#                 {
#                     center: [-34.6004232609843, -58.38300902393554],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f284c1a1e4c0cdc00f795aa9c8ff96fb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6ef122c3d9d735582e2f4798c3af9677);
#
#
#             var poly_line_8c99ac730e49b10402cb84733289b0f2 = L.polyline(
#                 [[-34.588850218149815, -58.38153690012031], [-34.59315242757882, -58.382420174409454], [-34.59327361335069, -58.38227296202792], [-34.6041796088788, -58.38153690012031], [-34.61393279363598, -58.38107550326964], [-34.62211391663683, -58.38089990008334]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6ef122c3d9d735582e2f4798c3af9677);
#
#
#             poly_line_8c99ac730e49b10402cb84733289b0f2.bindTooltip(
#                 `&lt;div&gt;
#                      Avda 9 de Julio
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## folium.Icon
# ##### icon=
#
# - "cloud": Un ícono de nube.
# - "cloud-download": Un ícono de nube con una flecha hacia abajo.
# - "cloud-upload": Un ícono de nube con una flecha hacia arriba.
# - "info-sign": Un ícono de signo de información.
# - "exclamation-sign": Un ícono de signo de exclamación.
# - "question-sign": Un ícono de signo de interrogación.
# - "ok-sign": Un ícono de signo de verificación.
# - "remove-sign": Un ícono de signo de eliminación.
# - "flag": Un ícono de bandera.
# - "star": Un ícono de estrella.

# %% [markdown]
# ---

# %% [markdown]
# ## Direcciones

# %%
geolocalizador = Nominatim(user_agent='mi_app_de_geolocalizacion')

# %%
una_direccion = geolocalizador.geocode('Cerrito 628, C1010AAN CABA')
una_direccion

# %%
una_direccion = geolocalizador.geocode('Cerrito 628, CABA, Argentina')
una_direccion
# Out:
# Location(Teatro Colón, 628, Cerrito, Microcentro, San Nicolás, Buenos Aires, Comuna 1, Ciudad Autónoma de Buenos Aires, C1010AAR, Argentina, (-34.601085499999996, -58.38318689897575, 0.0))

# %%
'Av. Sta. Fe 1860, C1123 CABA'.split(',')
# Out:
# ['Av. Sta. Fe 1860', ' C1123 CABA']

# %%
'Av. Sta. Fe 1860, C1123 CABA'.split(',')[0] + ', CABA, Argentina'
# Out:
# 'Av. Sta. Fe 1860, CABA, Argentina'

# %%
direcciones = {
    'Congreso de la Nación Argentina': 'Av. Entre Ríos, C1033 CABA',
    'El Ateneo Grand Splendid': 'Av. Sta. Fe 1860, C1123 CABA', 
    'Cementerio de la Recoleta': 'Junín 1760, C1113 CABA',
    'Teatro Colón': 'Cerrito 628, C1010AAN CABA',
    'Casa Rosada': 'Balcarce 78, C1064 CABA',
    'Museo Nacional de Bellas Artes': 'Av. del Libertador 1473, Buenos Aires',
    'Museo de Arte Latinoamericano de Buenos Aires': 'Figueroa Alcorta 3415, C1425CLA CABA',
    'Estadio Mâs Monumental': 'Figueroa Alcorta 7597, C1428 CABA',
    'Club Atlético Boca Juniors': 'Brandsen 805, C1161 CABA',
    'Parque Rivadavia': 'Av. Rivadavia 4950, C1424 CABA',
    'Club Ferro Carril Oeste': 'Av. Avellaneda 1240, Buenos Aires',
    'Facultad de Medicina de la Universidad de Buenos Aires': 'Paraguay 2155, C1121 ABG, Buenos Aires'
}

len(direcciones)
# Out:
# 12

# %%
centrar_mapa = geolocalizador.geocode([d.split(',')[0] + ', CABA, Argentina' for d in direcciones.values()][0])
centrar_mapa
# Out:
# Location(Avenida Entre Ríos, Balvanera, Buenos Aires, Comuna 3, Ciudad Autónoma de Buenos Aires, C1033AAH, Argentina, (-34.6097109, -58.3919114, 0.0))

# %%
centrar_mapa.latitude
# Out:
# -34.6097109

# %%
centrar_mapa.longitude
# Out:
# -58.3919114

# %%
centrar_mapa.address
# Out:
# 'Avenida Entre Ríos, Balvanera, Buenos Aires, Comuna 3, Ciudad Autónoma de Buenos Aires, C1033AAH, Argentina'

# %%
zoom = 13
mapa = folium.Map(location=[centrar_mapa.latitude, centrar_mapa.longitude], zoom_start=zoom)

# %%
direcciones.items()
# Out:
# dict_items([('Congreso de la Nación Argentina', 'Av. Entre Ríos, C1033 CABA'), ('El Ateneo Grand Splendid', 'Av. Sta. Fe 1860, C1123 CABA'), ('Cementerio de la Recoleta', 'Junín 1760, C1113 CABA'), ('Teatro Colón', 'Cerrito 628, C1010AAN CABA'), ('Casa Rosada', 'Balcarce 78, C1064 CABA'), ('Museo Nacional de Bellas Artes', 'Av. del Libertador 1473, Buenos Aires'), ('Museo de Arte Latinoamericano de Buenos Aires', 'Figueroa Alcorta 3415, C1425CLA CABA'), ('Estadio Mâs Monumental', 'Figueroa Alcorta 7597, C1428 CABA'), ('Club Atlético Boca Juniors', 'Brandsen 805, C1161 CABA'), ('Parque Rivadavia', 'Av. Rivadavia 4950, C1424 CABA'), ('Club Ferro Carril Oeste', 'Av. Avellaneda 1240, Buenos Aires'), ('Facultad de Medicina de la Universidad de Buenos Aires', 'Paraguay 2155, C1121 ABG, Buenos Aires')])

# %%
sin_geo = []
localizados = []

for nombre, direccion in direcciones.items():
    localizacion = geolocalizador.geocode(direccion.split(',')[0] + ', CABA, Argentina')
    localizados.append(localizacion)
    try:
        latitud, longitud = localizacion.latitude, localizacion.longitude
        marcador = folium.Marker(location=[latitud, longitud], popup=nombre)
        marcador.add_to(mapa)
    except:
        sin_geo.append([nombre, direccion])

# %%
sin_geo
# Out:
# []

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36349d43c975bb30df75bc6f7716bd4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36349d43c975bb30df75bc6f7716bd4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36349d43c975bb30df75bc6f7716bd4c = L.map(
#                 &quot;map_36349d43c975bb30df75bc6f7716bd4c&quot;,
#                 {
#                     center: [-34.6097109, -58.3919114],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6bbce0e14d6f4b2e0ee9b6a5b70612e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#             var marker_e6516e8caec7e6c6968d3ad850defc88 = L.marker(
#                 [-34.6097109, -58.3919114],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_dfeaab39b47bce7eb641ba81778d8749 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_435b58d4bc8ab25c8c832babff253fc4 = $(`&lt;div id=&quot;html_435b58d4bc8ab25c8c832babff253fc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Congreso de la Nación Argentina&lt;/div&gt;`)[0];
#                 popup_dfeaab39b47bce7eb641ba81778d8749.setContent(html_435b58d4bc8ab25c8c832babff253fc4);
#
#
#
#         marker_e6516e8caec7e6c6968d3ad850defc88.bindPopup(popup_dfeaab39b47bce7eb641ba81778d8749)
#         ;
#
#
#
#
#             var marker_327fca90a1b0c472bcc9858548c72d07 = L.marker(
#                 [-34.59604349999999, -58.39425503672509],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_c4b0f0d3c957e046b4ea2dd156f13ef4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3489970366d91f6b4e7e6a7df61c2cb = $(`&lt;div id=&quot;html_b3489970366d91f6b4e7e6a7df61c2cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Ateneo Grand Splendid&lt;/div&gt;`)[0];
#                 popup_c4b0f0d3c957e046b4ea2dd156f13ef4.setContent(html_b3489970366d91f6b4e7e6a7df61c2cb);
#
#
#
#         marker_327fca90a1b0c472bcc9858548c72d07.bindPopup(popup_c4b0f0d3c957e046b4ea2dd156f13ef4)
#         ;
#
#
#
#
#             var marker_eee340fc742b4a8c1863790d80cd820c = L.marker(
#                 [-34.5887709, -58.39249351717826],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_95faa24ef2b7b1500aeec484a0700220 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72adda0b7dfba664de6e9cc6122838ea = $(`&lt;div id=&quot;html_72adda0b7dfba664de6e9cc6122838ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cementerio de la Recoleta&lt;/div&gt;`)[0];
#                 popup_95faa24ef2b7b1500aeec484a0700220.setContent(html_72adda0b7dfba664de6e9cc6122838ea);
#
#
#
#         marker_eee340fc742b4a8c1863790d80cd820c.bindPopup(popup_95faa24ef2b7b1500aeec484a0700220)
#         ;
#
#
#
#
#             var marker_b07a2a42c3e3d9155a0c94dad333a4f0 = L.marker(
#                 [-34.601085499999996, -58.38318689897575],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_d964821db4633eebad7d2e458f057497 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_687d93b39ebd93340e10f66bb503bb0a = $(`&lt;div id=&quot;html_687d93b39ebd93340e10f66bb503bb0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Teatro Colón&lt;/div&gt;`)[0];
#                 popup_d964821db4633eebad7d2e458f057497.setContent(html_687d93b39ebd93340e10f66bb503bb0a);
#
#
#
#         marker_b07a2a42c3e3d9155a0c94dad333a4f0.bindPopup(popup_d964821db4633eebad7d2e458f057497)
#         ;
#
#
#
#
#             var marker_0e9b27280ff78d30e5eafa9ae6684821 = L.marker(
#                 [-34.6138208, -58.3707377],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_9763445e6df70ce6eeced38a220c2862 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf3242aeffbc2ea878042242bfe30c91 = $(`&lt;div id=&quot;html_cf3242aeffbc2ea878042242bfe30c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Casa Rosada&lt;/div&gt;`)[0];
#                 popup_9763445e6df70ce6eeced38a220c2862.setContent(html_cf3242aeffbc2ea878042242bfe30c91);
#
#
#
#         marker_0e9b27280ff78d30e5eafa9ae6684821.bindPopup(popup_9763445e6df70ce6eeced38a220c2862)
#         ;
#
#
#
#
#             var marker_b34

# %%
localizados
# Out:
# [Location(Avenida Entre Ríos, Balvanera, Buenos Aires, Comuna 3, Ciudad Autónoma de Buenos Aires, C1033AAH, Argentina, (-34.6097109, -58.3919114, 0.0)),
#  Location(El Ateneo Grand Splendid, 1860, Avenida Santa Fe, Barrio Norte, Recoleta, Buenos Aires, Comuna 2, Ciudad Autónoma de Buenos Aires, C1123AAN, Argentina, (-34.59604349999999, -58.39425503672509, 0.0)),
#  Location(Junín, La Isla, Recoleta, Buenos Aires, Comuna 2, Ciudad Autónoma de Buenos Aires, Argentina, (-34.5887709, -58.39249351717826, 0.0)),
#  Location(Teatro Colón, 628, Cerrito, Microcentro, San Nicolás, Buenos Aires, Comuna 1, Ciudad Autónoma de Buenos Aires, C1010AAR, Argentina, (-34.601085499999996, -58.38318689897575, 0.0)),
#  Location(Balcarce, Monserrat, Buenos Aires, Comuna 1, Ciudad Autónoma de Buenos Aires, C1098AAH, Argentina, (-34.6138208, -58.3707377, 0.0)),
#  Location(Museo Nacional de Bellas Artes, 1473, Avenida Del Libertador, La Isla, Recoleta, Buenos Aires, Comuna 2, Ciudad Autónoma de Buenos Aires, C1425AAA, Argentina, (-34.5839152, -58.392915186234035, 0.0)),
#  Location(Le Parc, Palermo, Buenos Aires, Comuna 14, Ciudad Autónoma de Buenos Aires, Argentina, (-34.57559755, -58.40478437557426, 0.0)),
#  Location(Universidad Torcuato DiTella - Campus Alcorta, 7350, Avenida Presidente Figueroa Alcorta, Barrio River, Belgrano, Buenos Aires, Comuna 13, Ciudad Autónoma de Buenos Aires, C1424BCL, Argentina, (-34.5477792, -58.44666747868682, 0.0)),
#  Location(La Bombonera, 805, Brandsen, La Boca, Buenos Aires, Distrito de Las Artes, Comuna 4, Ciudad Autónoma de Buenos Aires, C1161AAQ, Argentina, (-34.6356227, -58.36487449354664, 0.0)),
#  Location(Escuela Normal Superior 04 Estanislao Severo Zeballos, 4950, Avenida Rivadavia, Caballito, Buenos Aires, Comuna 6, Ciudad Autónoma de Buenos Aires, 1424, Argentina, (-34.6180751, -58.4352658, 0.0)),
#  Location(1240, Avenida Avellaneda, Caballito, Buenos Aires, Comuna 6, Ciudad Autónoma de Buenos Aires, C1405AME, Argentina, (-34.61863907346939, -58.44942045510204, 0.0)),
#  Location(Facultad de Medicina, 2155, Paraguay, Barrio Norte, Recoleta, Buenos Aires, Comuna 2, Ciudad Autónoma de Buenos Aires, C1121ABG, Argentina, (-34.5978066, -58.39826940019085, 0.0))]

# %%
localizados[1].raw
# Out:
# {'place_id': 354745730,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 477384752,
#  'boundingbox': ['-34.596167', '-34.5959425', '-58.3943896', '-58.3941225'],
#  'lat': '-34.59604349999999',
#  'lon': '-58.39425503672509',
#  'display_name': 'El Ateneo Grand Splendid, 1860, Avenida Santa Fe, Barrio Norte, Recoleta, Buenos Aires, Comuna 2, Ciudad Autónoma de Buenos Aires, C1123AAN, Argentina',
#  'class': 'shop',
#  'type': 'books',
#  'importance': 0.4200099999999999}

# %%
[x.raw['class'] for x in localizados]
# Out:
# ['highway',
#  'shop',
#  'highway',
#  'tourism',
#  'highway',
#  'tourism',
#  'landuse',
#  'amenity',
#  'leisure',
#  'amenity',
#  'place',
#  'amenity']

# %%
[x.raw['boundingbox'] for x in localizados]
# Out:
# [['-34.6103479', '-34.6092277', '-58.3919583', '-58.3918605'],
#  ['-34.596167', '-34.5959425', '-58.3943896', '-58.3941225'],
#  ['-34.5892119', '-34.5882499', '-58.3929109', '-58.3919965'],
#  ['-34.6013592', '-34.6008023', '-58.383815', '-58.3825435'],
#  ['-34.6159073', '-34.6123729', '-58.3707377', '-58.3705665'],
#  ['-34.584172', '-34.5836785', '-58.3933318', '-58.3924372'],
#  ['-34.5763422', '-34.5749381', '-58.4055509', '-58.4040159'],
#  ['-34.5486104', '-34.5471595', '-58.4475074', '-58.4458649'],
#  ['-34.6366024', '-34.6346969', '-58.3657692', '-58.3638'],
#  ['-34.6181251', '-34.6180251', '-58.4353158', '-58.4352158'],
#  ['-34.618689073469',
#   '-34.618589073469',
#   '-58.449470455102',
#   '-58.449370455102'],
#  ['-34.5983949', '-34.5972022', '-58.3988833', '-58.3974696']]

# %%
for location in localizados:
    try:
        loc_boundingbox = location.raw['boundingbox']
        loc_boundingbox = [float(x) for x in loc_boundingbox]
        print(loc_boundingbox)
        bounding_box = folium.Rectangle(
            bounds=[(loc_boundingbox[0], loc_boundingbox[2]), (loc_boundingbox[1], loc_boundingbox[3])],
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.2
        )
        
        bounding_box.add_to(mapa)
            
    except:
        print('Error al crear la caja de', location)
# Out:
# [-34.6103479, -34.6092277, -58.3919583, -58.3918605]
# [-34.596167, -34.5959425, -58.3943896, -58.3941225]
# [-34.5892119, -34.5882499, -58.3929109, -58.3919965]
# [-34.6013592, -34.6008023, -58.383815, -58.3825435]
# [-34.6159073, -34.6123729, -58.3707377, -58.3705665]
# [-34.584172, -34.5836785, -58.3933318, -58.3924372]
# [-34.5763422, -34.5749381, -58.4055509, -58.4040159]
# [-34.5486104, -34.5471595, -58.4475074, -58.4458649]
# [-34.6366024, -34.6346969, -58.3657692, -58.3638]
# [-34.6181251, -34.6180251, -58.4353158, -58.4352158]
# [-34.618689073469, -34.618589073469, -58.449470455102, -58.449370455102]
# [-34.5983949, -34.5972022, -58.3988833, -58.3974696]

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36349d43c975bb30df75bc6f7716bd4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36349d43c975bb30df75bc6f7716bd4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36349d43c975bb30df75bc6f7716bd4c = L.map(
#                 &quot;map_36349d43c975bb30df75bc6f7716bd4c&quot;,
#                 {
#                     center: [-34.6097109, -58.3919114],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6bbce0e14d6f4b2e0ee9b6a5b70612e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#             var marker_e6516e8caec7e6c6968d3ad850defc88 = L.marker(
#                 [-34.6097109, -58.3919114],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_dfeaab39b47bce7eb641ba81778d8749 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_435b58d4bc8ab25c8c832babff253fc4 = $(`&lt;div id=&quot;html_435b58d4bc8ab25c8c832babff253fc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Congreso de la Nación Argentina&lt;/div&gt;`)[0];
#                 popup_dfeaab39b47bce7eb641ba81778d8749.setContent(html_435b58d4bc8ab25c8c832babff253fc4);
#
#
#
#         marker_e6516e8caec7e6c6968d3ad850defc88.bindPopup(popup_dfeaab39b47bce7eb641ba81778d8749)
#         ;
#
#
#
#
#             var marker_327fca90a1b0c472bcc9858548c72d07 = L.marker(
#                 [-34.59604349999999, -58.39425503672509],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_c4b0f0d3c957e046b4ea2dd156f13ef4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3489970366d91f6b4e7e6a7df61c2cb = $(`&lt;div id=&quot;html_b3489970366d91f6b4e7e6a7df61c2cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Ateneo Grand Splendid&lt;/div&gt;`)[0];
#                 popup_c4b0f0d3c957e046b4ea2dd156f13ef4.setContent(html_b3489970366d91f6b4e7e6a7df61c2cb);
#
#
#
#         marker_327fca90a1b0c472bcc9858548c72d07.bindPopup(popup_c4b0f0d3c957e046b4ea2dd156f13ef4)
#         ;
#
#
#
#
#             var marker_eee340fc742b4a8c1863790d80cd820c = L.marker(
#                 [-34.5887709, -58.39249351717826],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_95faa24ef2b7b1500aeec484a0700220 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72adda0b7dfba664de6e9cc6122838ea = $(`&lt;div id=&quot;html_72adda0b7dfba664de6e9cc6122838ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cementerio de la Recoleta&lt;/div&gt;`)[0];
#                 popup_95faa24ef2b7b1500aeec484a0700220.setContent(html_72adda0b7dfba664de6e9cc6122838ea);
#
#
#
#         marker_eee340fc742b4a8c1863790d80cd820c.bindPopup(popup_95faa24ef2b7b1500aeec484a0700220)
#         ;
#
#
#
#
#             var marker_b07a2a42c3e3d9155a0c94dad333a4f0 = L.marker(
#                 [-34.601085499999996, -58.38318689897575],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_d964821db4633eebad7d2e458f057497 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_687d93b39ebd93340e10f66bb503bb0a = $(`&lt;div id=&quot;html_687d93b39ebd93340e10f66bb503bb0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Teatro Colón&lt;/div&gt;`)[0];
#                 popup_d964821db4633eebad7d2e458f057497.setContent(html_687d93b39ebd93340e10f66bb503bb0a);
#
#
#
#         marker_b07a2a42c3e3d9155a0c94dad333a4f0.bindPopup(popup_d964821db4633eebad7d2e458f057497)
#         ;
#
#
#
#
#             var marker_0e9b27280ff78d30e5eafa9ae6684821 = L.marker(
#                 [-34.6138208, -58.3707377],
#                 {}
#             ).addTo(map_36349d43c975bb30df75bc6f7716bd4c);
#
#
#         var popup_9763445e6df70ce6eeced38a220c2862 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf3242aeffbc2ea878042242bfe30c91 = $(`&lt;div id=&quot;html_cf3242aeffbc2ea878042242bfe30c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Casa Rosada&lt;/div&gt;`)[0];
#                 popup_9763445e6df70ce6eeced38a220c2862.setContent(html_cf3242aeffbc2ea878042242bfe30c91);
#
#
#
#         marker_0e9b27280ff78d30e5eafa9ae6684821.bindPopup(popup_9763445e6df70ce6eeced38a220c2862)
#         ;
#
#
#
#
#             var marker_b34

# %% [markdown]
# ## Guardar mapa

# %%
fecha = datetime.now().strftime('%Y%m%d_%H%M')
rnd_num = str(random.randint(100,999))

fecha, rnd_num
# Out:
# ('20230608_1837', '840')

# %%
nombre_del_mapa = fecha + '_Buenos_Aires_' + rnd_num + '.html'
m.save(nombre_del_mapa)

print(nombre_del_mapa, 'guardado ok')
# Out:
# 20230608_1837_Buenos_Aires_840.html guardado ok

# %% [markdown]
# ---

# %% [markdown]
# ## GEOJson

# %%
# https://github.com/alvarezgarcia/provincias-argentinas-geojson

# %%
location = geolocalizador.geocode('Argentina')
latitude = location.latitude
longitude = location.longitude

# %%
latitude
# Out:
# -34.9964963

# %%
mapa = folium.Map(location=[latitude, longitude], zoom_start=4)

# %%
#folium.GeoJson('cordoba_arg.json',name='Córdoba',).add_to(mapa);

# %%
mapa

# %%
location = geolocalizador.geocode("Argentina")
latitude = location.latitude
longitude = location.longitude
mapa = folium.Map(location=[latitude, longitude], zoom_start=5)

provincias = ["Buenos Aires", "La Pampa", "Santa Fe", "Salta"]

for provincia in provincias:
    location = geolocalizador.geocode(provincia)
    if location is not None:
        folium.Marker(
            location=[location.latitude, location.longitude],
            popup=provincia,
            icon=folium.Icon(icon="star")
        ).add_to(mapa)


mapa

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Heat Map
# ###### HEATMAP https://python-visualization.github.io/folium/plugins.html

# %%
df =  pd.read_csv('https://raw.githubusercontent.com/JJTorresDS/ds-data-sources/main/properati_venta_201501.csv')
df.shape
# Out:
# (18891, 10)

# %%
df.head()
# Out:
#                                          id  created_on operation  \
# 0  8ebed78a3c75018c0351ef91a93e1098b03e75c8  2014-11-27      sell
# 1  8a6dc3c73890f7cce002f8ee6f03bf1d8c04858c  2014-11-19      sell
# 2  7222ebd6e652ea6c0df50c97988b8314a67b6a22  2014-09-03      sell
# 3  6cf16e0c074d7f0d426c36ada31faba4d6b157f0  2015-01-05      sell
# 4  d0e9ecf25d7215e5b1c29b4a6519f536ee6c0917  2014-12-01      sell
#
#   property_type country_name state_name                        lat_lon  \
# 0     apartment    Argentina    Córdoba  -31.4121796494,-64.1712732402
# 1         house    Argentina    Córdoba        -31.3686142,-64.2264862
# 2         store    Argentina    Córdoba  -32.6521427143,-62.3049577995
# 3         house    Argentina    Córdoba         -31.3183975,-64.290657
# 4     apartment    Argentina    Córdoba  -31.4017318015,-64.2206747204
#
#    surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2
# 0                 62.0                   62.0        888.847742
# 1                240.0                  180.0        487.503625
# 2              10000.0                 1000.0        160.000000
# 3                325.0                16250.0        256.004892
# 4                 78.0                   78.0        535.467821

# %%
df['country_name'].value_counts()
# Out:
# Argentina    18891
# Name: country_name, dtype: int64

# %%
df['state_name'].value_counts()
# Out:
# Buenos Aires Costa Atlántica    4105
# Capital Federal                 4057
# Bs.As. G.B.A. Zona Norte        3500
# Bs.As. G.B.A. Zona Oeste        2611
# Bs.As. G.B.A. Zona Sur          1266
# Santa Fe                        1116
# Buenos Aires Interior            740
# Córdoba                          634
# Río Negro                        143
# Misiones                         131
# Neuquén                          117
# Entre Ríos                       105
# La Pampa                          97
# Mendoza                           78
# Salta                             65
# San Luis                          27
# La Rioja                          18
# Tucumán                           16
# Chaco                             15
# Catamarca                         14
# San Juan                          12
# Corrientes                         8
# Chubut                             6
# Jujuy                              5
# Formosa                            2
# Santa Cruz                         2
# Tierra Del Fuego                   1
# Name: state_name, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'created_on', 'operation', 'property_type', 'country_name',
#        'state_name', 'lat_lon', 'surface_total_in_m2', 'surface_covered_in_m2',
#        'price_usd_per_m2'],
#       dtype='object')

# %%
df['lat_lon']
# Out:
# 0        -31.4121796494,-64.1712732402
# 1              -31.3686142,-64.2264862
# 2        -32.6521427143,-62.3049577995
# 3               -31.3183975,-64.290657
# 4        -31.4017318015,-64.2206747204
#                      ...
# 18886                              NaN
# 18887          -38.6932635,-62.2709836
# 18888          -34.3649989,-58.7406683
# 18889                              NaN
# 18890                              NaN
# Name: lat_lon, Length: 18891, dtype: object

# %%
df['lat_lon'].str.split(',')
# Out:
# 0        [-31.4121796494, -64.1712732402]
# 1              [-31.3686142, -64.2264862]
# 2        [-32.6521427143, -62.3049577995]
# 3               [-31.3183975, -64.290657]
# 4        [-31.4017318015, -64.2206747204]
#                        ...
# 18886                                 NaN
# 18887          [-38.6932635, -62.2709836]
# 18888          [-34.3649989, -58.7406683]
# 18889                                 NaN
# 18890                                 NaN
# Name: lat_lon, Length: 18891, dtype: object

# %%
df['lat_lon'].str.split(',', expand=True)
# Out:
#                     0               1
# 0      -31.4121796494  -64.1712732402
# 1         -31.3686142     -64.2264862
# 2      -32.6521427143  -62.3049577995
# 3         -31.3183975      -64.290657
# 4      -31.4017318015  -64.2206747204
# ...               ...             ...
# 18886             NaN             NaN
# 18887     -38.6932635     -62.2709836
# 18888     -34.3649989     -58.7406683
# 18889             NaN             NaN
# 18890             NaN             NaN
#
# [18891 rows x 2 columns]

# %%
df[['lat', 'lon']] = df['lat_lon'].str.split(',', expand=True)
df.shape
# Out:
# (18891, 12)

# %%
df.head()
# Out:
#                                          id  created_on operation  \
# 0  8ebed78a3c75018c0351ef91a93e1098b03e75c8  2014-11-27      sell
# 1  8a6dc3c73890f7cce002f8ee6f03bf1d8c04858c  2014-11-19      sell
# 2  7222ebd6e652ea6c0df50c97988b8314a67b6a22  2014-09-03      sell
# 3  6cf16e0c074d7f0d426c36ada31faba4d6b157f0  2015-01-05      sell
# 4  d0e9ecf25d7215e5b1c29b4a6519f536ee6c0917  2014-12-01      sell
#
#   property_type country_name state_name                        lat_lon  \
# 0     apartment    Argentina    Córdoba  -31.4121796494,-64.1712732402
# 1         house    Argentina    Córdoba        -31.3686142,-64.2264862
# 2         store    Argentina    Córdoba  -32.6521427143,-62.3049577995
# 3         house    Argentina    Córdoba         -31.3183975,-64.290657
# 4     apartment    Argentina    Córdoba  -31.4017318015,-64.2206747204
#
#    surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# 0                 62.0                   62.0        888.847742
# 1                240.0                  180.0        487.503625
# 2              10000.0                 1000.0        160.000000
# 3                325.0                16250.0        256.004892
# 4                 78.0                   78.0        535.467821
#
#               lat             lon
# 0  -31.4121796494  -64.1712732402
# 1     -31.3686142     -64.2264862
# 2  -32.6521427143  -62.3049577995
# 3     -31.3183975      -64.290657
# 4  -31.4017318015  -64.2206747204

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18891 entries, 0 to 18890
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     18891 non-null  object
#  1   created_on             18891 non-null  object
#  2   operation              18891 non-null  object
#  3   property_type          18891 non-null  object
#  4   country_name           18891 non-null  object
#  5   state_name             18891 non-null  object
#  6   lat_lon                16176 non-null  object
#  7   surface_total_in_m2    10941 non-null  float64
#  8   surface_covered_in_m2  12920 non-null  float64
#  9   price_usd_per_m2       8541 non-null   float64
#  10  lat                    16176 non-null  object
#  11  lon                    16176 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.7+ MB

# %%
df['created_on'] = pd.to_datetime(df['created_on'])
df.shape
# Out:
# (18891, 12)

# %%
df.isnull().sum()
# Out:
# id                           0
# created_on                   0
# operation                    0
# property_type                0
# country_name                 0
# state_name                   0
# lat_lon                   2715
# surface_total_in_m2       7950
# surface_covered_in_m2     5971
# price_usd_per_m2         10350
# lat                       2715
# lon                       2715
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# id                       0
# created_on               0
# operation                0
# property_type            0
# country_name             0
# state_name               0
# lat_lon                  0
# surface_total_in_m2      0
# surface_covered_in_m2    0
# price_usd_per_m2         0
# lat                      0
# lon                      0
# dtype: int64

# %%
df.shape
# Out:
# (6032, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6032 entries, 0 to 18888
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6032 non-null   object
#  1   created_on             6032 non-null   datetime64[ns]
#  2   operation              6032 non-null   object
#  3   property_type          6032 non-null   object
#  4   country_name           6032 non-null   object
#  5   state_name             6032 non-null   object
#  6   lat_lon                6032 non-null   object
#  7   surface_total_in_m2    6032 non-null   float64
#  8   surface_covered_in_m2  6032 non-null   float64
#  9   price_usd_per_m2       6032 non-null   float64
#  10  lat                    6032 non-null   object
#  11  lon                    6032 non-null   object
# dtypes: datetime64[ns](1), float64(3), object(8)
# memory usage: 612.6+ KB

# %%
df['lat'].astype(float)
# Out:
# 0       -31.412180
# 1       -31.368614
# 2       -32.652143
# 3       -31.318397
# 4       -31.401732
#            ...
# 18881   -34.561672
# 18882   -34.638594
# 18883   -34.651902
# 18887   -38.693264
# 18888   -34.364999
# Name: lat, Length: 6032, dtype: float64

# %%
df['lat'] = df['lat'].astype(float)
df['lon'] = df['lon'].astype(float)
df.shape
# Out:
# (6032, 12)

# %% [markdown]
# ---

# %% [markdown]
# ## Heat Map

# %%
max_amount = df['price_usd_per_m2'].max()

# %%
max_amount
# Out:
# 51623.06451612903

# %%
folium_hmap = folium.Map(location=[-31, -64],
                        zoom_start=5,
                        # tiles="OpenStreetMap"
                        )

# %%
zip(df['lat'], df['lon'], df['price_usd_per_m2'])

# %%
list(zip(df['lat'], df['lon'], df['price_usd_per_m2']))[:5]
# Out:
# [(-31.4121796494, -64.1712732402, 888.8477419354839),
#  (-31.3686142, -64.2264862, 487.503625),
#  (-32.6521427143, -62.3049577995, 160.0),
#  (-31.3183975, -64.290657, 256.0048923076923),
#  (-31.4017318015, -64.2206747204, 535.4678205128205)]

# %%
hm_wide = HeatMap(data=list(zip(df['lat'], df['lon'], df['price_usd_per_m2'])),
                  # name='Precio por M2',
                   min_opacity=0.8,
                   radius=10, blur=6, 
                   max_zoom=15, 
                 )

# %%
folium_hmap.add_child(hm_wide)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e5b01852072d0e62ff66110f3395d48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e5b01852072d0e62ff66110f3395d48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e5b01852072d0e62ff66110f3395d48 = L.map(
#                 &quot;map_9e5b01852072d0e62ff66110f3395d48&quot;,
#                 {
#                     center: [-31.0, -64.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ccc639e399363ffe2b7f29e882aceb2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e5b01852072d0e62ff66110f3395d48);
#
#
#             var heat_map_597c348d08968f67fd564b3b4650b6fb = L.heatLayer(
#                 [[-31.4121796494, -64.1712732402, 888.8477419354839], [-31.3686142, -64.2264862, 487.503625], [-32.6521427143, -62.3049577995, 160.0], [-31.3183975, -64.290657, 256.0048923076923], [-31.4017318015, -64.2206747204, 535.4678205128205], [-31.3616123, -64.2456207, 3061.2244897959185], [-31.396369507, -64.1928930753, 1308.4839622641507], [-31.3845912, -64.225213, 498.0001169590644], [-31.4612485224, -64.1413163677, 1023.6884705882352], [-31.4127589197, -64.169508955, 1794.763260869565], [-31.4117649, -64.1587679, 962.7278688524592], [-31.4094326837, -64.1723890391, 999.044074074074], [-31.3928772, -64.1471481, 345.9861591695501], [-31.4109917, -64.1643344, 1043.372738095238], [-31.2746260642, -64.2927789878, 200.0], [-31.3407511, -64.2722453, 346.0410344827586], [-31.4332333, -64.1497498, 115.75562], [-31.4028490022, -64.2212755352, 558.1998113207547], [-31.2579686355, -64.4529952629, 849.354705882353], [-31.4169646, -64.2075523, 740.0], [-31.3790971, -64.2254192, 950.8127710843373], [-31.3761425687, -64.2417270643, 250.0], [-31.4117431629, -64.1686968315, 676.9262121212121], [-38.952444, -68.064139, 957.3012727272728], [-33.3093987, -66.3433609, 18.592628205128204], [-33.6707637, -65.4596152, 564.2067142857143], [-32.4766270746, -58.2427468239, 438.08741935483874], [-24.8003464, -65.4077377, 578.793448275862], [-38.416097, -63.616672, 199.0974], [-38.416097, -63.616672, 55.92623595505618], [-34.59733, -58.4051, 2675.0], [-34.5948419, -58.3932157, 3233.823529411765], [-32.90783, -68.8253128, 4027.445433526012], [-32.90783, -68.8253128, 4027.445433526012], [-32.90783, -68.8253128, 4223.454624277457], [-27.480077, -55.11635, 162.83362857142856], [-31.4852865251, -64.532164184, 140.78088319088317], [-31.4043257, -64.4792369, 236.83721739130436], [-31.4202675, -64.6214281, 67.67718333333333], [-31.4202675, -64.6214281, 71.69652808988765], [-31.4261827, -64.4998506, 158.2064], [-31.4106977, -64.4824287, 49.08453846153847], [-31.4304256, -64.1315079, 213.4477434679335], [-31.4202675, -64.6214281, 342.0522885572139], [-31.4304256, -64.1315079, 150.0], [-31.3333302, -64.5999985, 869.7967105263158], [-31.4181895812, -64.4861801391, 260.6894266666667], [-31.421767026, -64.4864533405, 330.0], [-30.8744002513, -64.524809732, 152.34842857142857], [-31.4166964022, -64.4911681217, 682.4589411764706], [-31.4266806, -64.4974968, 72.51126666666667], [-31.4207948, -64.4883095, 220.0], [-31.4304256, -64.1315079, 103.12713333333332], [-31.4202675, -64.6214281, 701.9578151260504], [-31.408798, -64.5059886, 557.2955400000001], [-31.4847009696, -64.5314775385, 84.81089686098655], [-31.4316994, -64.4957741, 385.5505384615385], [-34.615974, -58.438168, 799.8122826086956], [-31.4316994, -64.4957741, 245.27576666666664], [-27.397005, -55.907688, 691.2397402597403], [-27.3709934565, -55.8975344936, 1504.531875], [-27.3651927137, -55.9445562768, 214.17860869565217], [-27.3775819989, -55.8991257997, 16866.126944444444], [-27.3880711, -55.9271736, 128.65653531598514], [-38.416097, -63.616672, 2521.9], [-27.3709934565, -55.8975344936, 933.31], [-27.381158, -55.8970892, 629.025763888889], [-27.3911934, -55.8988609, 1062.5], [-27.387831, -55.913832, 620.3268529411765], [-27.3786395083, -55.943017468, 346.63666666666666], [-27.3661423, -55.9240761, 126.30041505791506], [-27.3711224, -55.9269638, 352.6746568627451], [-32.9368263, -60.6574113, 1553.1445161290324], [-32.9556963, -60.6363391, 1311.7286792452828], [-32.957523, -60.6258765, 1714.2857142857142], [-32.9368263, -60.6574113, 1171.6460714285713], [-32.9552678, -60.631636, 1356.906304347826], [-33.0024335, -60.6701991, 874.431851851852], [-32.9498099, -60.656005, 1970.8533333333328], [-32.9368263, -60.6574113, 517.3775675675676], [-32.9494976, -60.6357891, 1855.581081081081], [-32.9418888, -60.6399881, 1530.68], [-32.9713024, -60.6559696, 1084.8575308641975], [-33.002433

# %% [markdown]
# ---

# %% [markdown]
# ## Desde DF

# %%
df['state_name'].value_counts()
# Out:
# Capital Federal                 1904
# Bs.As. G.B.A. Zona Norte        1284
# Buenos Aires Costa Atlántica    1201
# Bs.As. G.B.A. Zona Oeste         846
# Bs.As. G.B.A. Zona Sur           244
# Buenos Aires Interior            208
# Santa Fe                         143
# Córdoba                          112
# Misiones                          27
# La Pampa                          15
# San Luis                          12
# Neuquén                            6
# Tucumán                            5
# Mendoza                            5
# Salta                              5
# Entre Ríos                         4
# Jujuy                              3
# Río Negro                          2
# Chaco                              2
# Santa Cruz                         2
# San Juan                           1
# La Rioja                           1
# Name: state_name, dtype: int64

# %%
caba = df[df['state_name']=='Capital Federal'].sample(100).copy()

# %%
caba.head()
# Out:
#                                              id created_on operation  \
# 939    5b12c5b7027bb332ba0f0e42f83250c8d693f2fa 2014-08-26      sell
# 18654  2aac99f89adcb96fa529beb0883b4681be513593 2014-09-29      sell
# 15932  53b97c32e7e6b1859aa6578ee8e5b16f3e53bc80 2014-11-27      sell
# 789    84275ee7788d015a6f50fcb4cebb16edc93fda79 2014-11-12      sell
# 675    e59f33d3c82733112317f89a25d8536c220a8066 2014-12-12      sell
#
#       property_type country_name       state_name  \
# 939       apartment    Argentina  Capital Federal
# 18654         house    Argentina  Capital Federal
# 15932     apartment    Argentina  Capital Federal
# 789       apartment    Argentina  Capital Federal
# 675       apartment    Argentina  Capital Federal
#
#                              lat_lon  surface_total_in_m2  \
# 939    -34.5930924078,-58.4490665103                 51.0
# 18654          -34.580556,-58.468333                400.0
# 15932        -34.6490898,-58.4851532                 38.0
# 789          -34.6242047,-58.4817323                 52.0
# 675    -34.5648579387,-58.4541266417                145.0
#
#        surface_covered_in_m2  price_usd_per_m2        lat        lon
# 939                     49.0       1254.901961 -34.593092 -58.449067
# 18654                  290.0       2000.000000 -34.580556 -58.468333
# 15932                   48.0       2500.000000 -34.649090 -58.485153
# 789                     44.0       1832.399615 -34.624205 -58.481732
# 675                    125.0       1931.034483 -34.564858 -58.454127

# %%
direcciones_caba = list(zip(caba['lat'], caba['lon'], caba['price_usd_per_m2'].round(2)))
direcciones_caba[0]
# Out:
# (-34.5930924078, -58.4490665103, 1254.9)

# %%
mapa = folium.Map(location=[direcciones_caba[0][0], direcciones_caba[0][1]], zoom_start=12)

# %%
for location in direcciones_caba:
    #localizacion = geolocalizador.geocode(direccion.split(',')[0] + ', CABA, Argentina')
    #localizados.append(localizacion)
    #try:
    # latitud, longitud = localizacion.latitude, localizacion.longitude
    marcador = folium.Marker(location=[location[0], location[1]], popup=location[2])
    marcador.add_to(mapa)
    #except:
    #sin_geo.append([nombre, direccion])

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8817630f5a55297bd648fac520ac2b82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8817630f5a55297bd648fac520ac2b82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8817630f5a55297bd648fac520ac2b82 = L.map(
#                 &quot;map_8817630f5a55297bd648fac520ac2b82&quot;,
#                 {
#                     center: [-34.5930924078, -58.4490665103],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62ea898ba767583c2cc335927a287827 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8817630f5a55297bd648fac520ac2b82);
#
#
#             var marker_0a71243f82e381ee9a215979e70cfda4 = L.marker(
#                 [-34.5930924078, -58.4490665103],
#                 {}
#             ).addTo(map_8817630f5a55297bd648fac520ac2b82);
#
#
#         var popup_8b2d18aa41e9d01c048ecd17b4554258 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a313f9e2b8a5e5936e18533ee6ee5300 = $(`&lt;div id=&quot;html_a313f9e2b8a5e5936e18533ee6ee5300&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1254.9&lt;/div&gt;`)[0];
#                 popup_8b2d18aa41e9d01c048ecd17b4554258.setContent(html_a313f9e2b8a5e5936e18533ee6ee5300);
#
#
#
#         marker_0a71243f82e381ee9a215979e70cfda4.bindPopup(popup_8b2d18aa41e9d01c048ecd17b4554258)
#         ;
#
#
#
#
#             var marker_9d46ea42dec9add4185ce18ed2c03c6b = L.marker(
#                 [-34.580556, -58.468333],
#                 {}
#             ).addTo(map_8817630f5a55297bd648fac520ac2b82);
#
#
#         var popup_d1b27024ad0ddbc7d8e833267d8e2f62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d6b03df0c7e4eeea0341125bc07ef80 = $(`&lt;div id=&quot;html_3d6b03df0c7e4eeea0341125bc07ef80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2000.0&lt;/div&gt;`)[0];
#                 popup_d1b27024ad0ddbc7d8e833267d8e2f62.setContent(html_3d6b03df0c7e4eeea0341125bc07ef80);
#
#
#
#         marker_9d46ea42dec9add4185ce18ed2c03c6b.bindPopup(popup_d1b27024ad0ddbc7d8e833267d8e2f62)
#         ;
#
#
#
#
#             var marker_552a9bf22ad469649d081618ebd0d092 = L.marker(
#                 [-34.6490898, -58.4851532],
#                 {}
#             ).addTo(map_8817630f5a55297bd648fac520ac2b82);
#
#
#         var popup_f252c7ce7487119bc6c20d1292b47fd0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c20667f0a7e31ece60801fa6ec79669a = $(`&lt;div id=&quot;html_c20667f0a7e31ece60801fa6ec79669a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2500.0&lt;/div&gt;`)[0];
#                 popup_f252c7ce7487119bc6c20d1292b47fd0.setContent(html_c20667f0a7e31ece60801fa6ec79669a);
#
#
#
#         marker_552a9bf22ad469649d081618ebd0d092.bindPopup(popup_f252c7ce7487119bc6c20d1292b47fd0)
#         ;
#
#
#
#
#             var marker_634d47b510a97b95d5a2294efc77463d = L.marker(
#                 [-34.6242047, -58.4817323],
#                 {}
#             ).addTo(map_8817630f5a55297bd648fac520ac2b82);
#
#
#         var popup_3f0830e857af724adeb2aebdb412e72f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d3e77d56ffbfd80e7a0d4ddf5e433c6 = $(`&lt;div id=&quot;html_8d3e77d56ffbfd80e7a0d4ddf5e433c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1832.4&lt;/div&gt;`)[0];
#                 popup_3f0830e857af724adeb2aebdb412e72f.setContent(html_8d3e77d56ffbfd80e7a0d4ddf5e433c6);
#
#
#
#         marker_634d47b510a97b95d5a2294efc77463d.bindPopup(popup_3f0830e857af724adeb2aebdb412e72f)
#         ;
#
#
#
#
#             var marker_8558d2b23709844d5b87b07dbeb97c31 = L.marker(
#                 [-34.5648579387, -58.4541266417],
#                 {}
#             ).addTo(map_8817630f5a55297bd648fac520ac2b82);
#
#
#         var popup_64ea7b6d6450b4fcec66c19a2768a764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5833a48c03655a5acf8608538be296ba = $(`&lt;div id=&quot;html_5833a48c03655a5acf8608538be296ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1931.03&lt;/div&gt;`)[0];
#                 popup_64ea7b6d6450b4fcec66c19a2768a764.setContent(html_5833a48c03655a5acf8608538be296ba);
#
#
#
#         marker_8558d2b23709844d5b87b07dbeb97c31.bindPopup(popup_64ea7b6d6450b4fcec66c19a2768a764)
#         ;
#
#
#
#
#             var marker_765f4b499657f0516816931a5cd1a392 = L.marker(
#                 [-34.615974, -58.438168],

# %% [markdown]
# ---

# %% [markdown]
# ## Distancia

# %%
coord1 = (40.7128, -74.0060)  # Nueva York
coord2 = (34.0522, -118.2437)  # Los Ángeles

# %%
distancia = geodesic(coord1, coord2).kilometers

print(f"La distancia entre las coordenadas es de {distancia} kilómetros.")
# Out:
# La distancia entre las coordenadas es de 3944.4222314899216 kilómetros.

# %%
teatro_colon = (-34.60053037141119, -58.38348489577889) # [latitud (norte - sur), longitud (este - oeste)]

# %%
geodesic(coord2, teatro_colon).kilometers
# Out:
# 9831.069730111616

# %%
def calcular_distancia(row):
    distancia = round(geodesic((row['lat'], row['lon']), teatro_colon).kilometers, 2)
    return distancia

# %%
caba['kms_al_colon'] = df.apply(calcular_distancia, axis=1)

# %%
caba.sample(5)
# Out:
#                                              id created_on operation  \
# 16357  684dc161737b8244a271cf1a12282d15e33a3ba1 2014-09-17      sell
# 442    bf76423b886a5e0d16e2d699e7511eb623fd7341 2015-01-01      sell
# 381    7b12d22919eba550670a0734b5e4002da6092753 2014-11-07      sell
# 15653  c7fe4301f6a656adcb538363241a62aadc5656f3 2014-09-21      sell
# 17713  c76e8ad87baea937b248e98cc5db75d186a5eaad 2014-09-27      sell
#
#       property_type country_name       state_name  \
# 16357     apartment    Argentina  Capital Federal
# 442       apartment    Argentina  Capital Federal
# 381       apartment    Argentina  Capital Federal
# 15653     apartment    Argentina  Capital Federal
# 17713     apartment    Argentina  Capital Federal
#
#                              lat_lon  surface_total_in_m2  \
# 16357        -34.6130888,-58.3979085                 43.0
# 442             -34.61098,-58.417856                 77.0
# 381          -34.6268376,-58.4651375                 67.0
# 15653  -34.6076326044,-58.3861986863                 35.0
# 17713        -34.6036844,-58.3815591                 65.0
#
#        surface_covered_in_m2  price_usd_per_m2        lat        lon  \
# 16357                   43.0       1674.418605 -34.613089 -58.397908
# 442                     71.0       2262.090909 -34.610980 -58.417856
# 381                     57.0       1602.835821 -34.626838 -58.465137
# 15653                   33.0       2780.857143 -34.607633 -58.386199
# 17713                   60.0       2738.461538 -34.603684 -58.381559
#
#        kms_al_colon
# 16357          1.92
# 442            3.36
# 381            8.04
# 15653          0.83
# 17713          0.39
