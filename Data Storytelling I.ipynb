# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
data['Year'].unique()
# Out:
# array([2019, 2018], dtype=int64)

# %%
data
# Out:
#     Country or Area  Year                          Item        Value
# 0       Afghanistan  2019  Gross Domestic Product (GDP)   469.919090
# 1       Afghanistan  2018  Gross Domestic Product (GDP)   483.885875
# 2           Albania  2019  Gross Domestic Product (GDP)  5303.197823
# 3           Albania  2018  Gross Domestic Product (GDP)  5254.384798
# 4           Algeria  2019  Gross Domestic Product (GDP)  3975.510381
# ..              ...   ...                           ...          ...
# 419           Yemen  2018  Gross Domestic Product (GDP)   803.648363
# 420          Zambia  2019  Gross Domestic Product (GDP)  1292.482076
# 421          Zambia  2018  Gross Domestic Product (GDP)  1556.338275
# 422        Zimbabwe  2019  Gross Domestic Product (GDP)  1463.985913
# 423        Zimbabwe  2018  Gross Domestic Product (GDP)  1683.765768
#
# [424 rows x 4 columns]

# %%
switzerland_df = data[data['Country or Area'] == 'Switzerland']

# %%
plt.plot(switzerland_df['Year'], switzerland_df['Value'])

# %%
countries = ['Ireland', 'Norway', 'Switzerland', 'Cayman Islands']

# %%
fig, ax = plt.subplots(1, figsize=(6,6))

for country in countries:
    country_df = data[data['Country or Area'] == country]
    plt.plot(country_df['Year'], country_df['Value'])
    
    plt.text(country_df['Year'].values[0] + 0.02,country_df['Value'].values[0],
             country_df['Value'].iloc[0])
    plt.text(country_df['Year'].values[1] - 0.02,country_df['Value'].values[1], 
             country, ha='right')
    
    
plt.xlim(2017.5,2019.5)
plt.xticks([2018, 2019])

ax.xaxis.grid()

ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
